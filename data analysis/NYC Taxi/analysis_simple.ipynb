# %%
"""
sth we know after analysis: 
1. Group rides:
- there are no rides with RatecodeID='group_rides';
- why? Maybe 'cause we had only 31(!) courses with more than 6 passengers
- we don't need to but more "big" cars for group rides.
"""

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
taxi=pd.read_csv('datas.csv')
len(taxi)
# Out:
# 311734

# %%
taxi.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'improvement_surcharge', 'total_amount',
#        'payment_type', 'trip_type', 'Lpep_dropoff_datetime'],
#       dtype='object')

# %%
taxi.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-01-01 00:38:02   2018-01-01 00:55:02                  N
# 1         2  2018-01-01 00:57:59   2018-01-01 01:12:26                  N
# 2         2  2018-01-01 00:36:58   2018-01-01 00:51:08                  N
# 3         1  2018-01-01 00:07:40   2018-01-01 00:15:20                  N
# 4         1  2018-01-01 00:25:09   2018-01-01 00:42:04                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           189           225                5           3.45
# 1           1            97           188                1           2.71
# 2           1           244            75                2           6.01
# 3           1           225            37                1           1.90
# 4           1            36           145                2           4.30
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
small=taxi[:1000]
small.describe()
# Out:
#           VendorID   RatecodeID  PULocationID  DOLocationID  passenger_count  \
# count  1000.000000  1000.000000    1000.00000   1000.000000      1000.000000
# mean      1.841000     1.040000     122.92300    129.067000         1.449000
# std       0.365859     0.398194      84.43637     81.935303         1.128128
# min       1.000000     1.000000       7.00000      4.000000         1.000000
# 25%       2.000000     1.000000      42.00000     54.000000         1.000000
# 50%       2.000000     1.000000      97.00000    112.000000         1.000000
# 75%       2.000000     1.000000     188.25000    210.250000         1.000000
# max       2.000000     5.000000     260.00000    265.000000         6.000000
#
#        trip_distance  fare_amount        extra      mta_tax   tip_amount  \
# count    1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean        3.356080    13.423500     0.494500     0.495000     3.034520
# ...

# %%
"""
Max(RatecodeID) = 5
but should be: RatecodeID in [1,6]
6 - group rides
why? 'Cause we delete in the cleanig proces sth. Check:
"""
path='green_tripdata_2018-01.csv'
bef_clean=pd.read_csv(path)
bef_clean['passenger_count'].unique()
# Out:
# array([5, 1, 2, 4, 6, 3, 0, 8, 7, 9], dtype=int64)

# %%
#we have rides with +6 passengers. 
a=len(bef_clean[bef_clean.passenger_count>6])
print(a, "from",len(bef_clean))
#but only  31 rides! 2 after cleaning!
# Out:
# 31 from 793529

# %%
bef_clean[bef_clean.passenger_count>6].describe()
# but still - for 7 and 8 passengers we haven't 'group_rides'. Why???
# Out:
#        VendorID  RatecodeID  PULocationID  DOLocationID  passenger_count  \
# count      31.0        31.0     31.000000     31.000000        31.000000
# mean        2.0         5.0    145.290323    151.258065         7.483871
# std         0.0         0.0     72.447771     77.047590         0.625618
# min         2.0         5.0      7.000000      7.000000         7.000000
# 25%         2.0         5.0     76.500000     76.500000         7.000000
# 50%         2.0         5.0    146.000000    164.000000         7.000000
# 75%         2.0         5.0    194.000000    221.500000         8.000000
# max         2.0         5.0    264.000000    258.000000         9.000000
#
#        trip_distance  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# count      31.000000    31.000000   31.0     31.0   31.000000          31.0
# mean        0.826129    12.596129    0.0      0.0    0.803548           0.0
# std         1.918163    19.457574    0.0      0.0    1.838729           0.0
# ...
